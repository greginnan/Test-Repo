# %% [markdown]
# <h1>work</h1>
# <h3>Admin, etc.</h3>
# <ul>
# <li>email payroll about tax stuff</li>
# </ul>
# <h3>WGs</h3>
# <ul>
# <li>study WGs<ul>
# <li>flash cards</li>
# </ul>
# </li>
# <li>quick review of what vijay sent<ul>
# <li>anything about MATLAB license?</li>
# </ul>
# </li>
# <li>where do we want the email lists? Just internally? (ask #Mathew)</li>
# <li>get more info on Working Group Summit before doodle send<ul>
# <li>must send</li>
# </ul>
# </li>
# <li>change to chair of Cellular Neuroscience in MATLAB board, check vijay</li>
# <li>~~what was I supposed to add from Mathew, some guy?</li>
# </ul>
# <h2>TrainingSpace</h2>
# <ul>
# <li>~~follow up about final decision about R Workshop materials (maybe tomorrow)</li>
# <li>~~ask about course photos, KCNI emblem, etc.</li>
# <li>~~Neurotech EU course<ul>
# <li>~~follow up with mathew<ul>
# <li>~~descriptions?</li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# <h3>General</h3>
# <ul>
# <li>look up easily embeddable alternative to Obsidian<ul>
# <li>learn more about publish features on Obsidian</li>
# </ul>
# </li>
# <li>check out [[INCF Network Nodes]] for next steps re: obsidian viz</li>
# <li>~~registered reports blog post</li>
# <li>check Assembly status</li>
# <li>neurostars<ul>
# <li>should I make a log in or would i have one automatically with my incf.org email?</li>
# </ul>
# </li>
# </ul>
# <h1>home</h1>
# <ul>
# <li>german paperwork</li>
# <li></li>
# </ul>
